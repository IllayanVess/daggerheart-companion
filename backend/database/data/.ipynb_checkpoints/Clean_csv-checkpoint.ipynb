# %%
import pandas as pd

# %% [markdown]
# ## CLean classes/subclasses/domain

# %%
df_ancestry = pd.read_csv('./srd_ancestry.csv', sep=';')
df_armor = pd.read_csv('./srd_armor.csv', sep=';')
df_classes = pd.read_csv('./srd_classes.csv', sep=';')
df_community = pd.read_csv('./srd_community.csv', sep=';')
df_consumable = pd.read_csv('./srd_consumable.csv', sep=';')
df_domain_cards = pd.read_csv('./srd_domain_cards.csv', sep=';')
df_item = pd.read_csv('./srd_item.csv', sep=';')
df_subclass = pd.read_csv('./srd_subclass.csv', sep=';')
df_weapon = pd.read_csv('./srd_weapon.csv', sep=';')
